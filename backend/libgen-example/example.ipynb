# %%
from libgen_api import LibgenSearch
s = LibgenSearch()
results = s.search_title("introduction to the theory of computation")

results
# Out:
# [{'ID': '1417',
#   'Author': 'Eitan Gurari',
#   'Title': 'Introduction to the theory of computation',
#   'Publisher': 'Computer Science Pr',
#   'Year': '1989',
#   'Pages': '600',
#   'Language': 'English',
#   'Size': '6 Mb',
#   'Extension': 'pdf',
#   'Mirror_1': 'http://library.lol/main/8DD9011B86B30C55D43A77E0A6DF81AE',
#   'Mirror_2': 'http://libgen.lc/ads.php?md5=8DD9011B86B30C55D43A77E0A6DF81AE',
#   'Mirror_3': 'https://library.bz/main/edit/8DD9011B86B30C55D43A77E0A6DF81AE'},
#  {'ID': '1428',
#   'Author': 'Michael (Michael Sipser) Sipser',
#   'Title': 'Introduction to the theory of computation',
#   'Publisher': 'Thomson Course Technology',
#   'Year': '2006',
#   'Pages': '453',
#   'Language': 'English',
#   'Size': '5 Mb',
#   'Extension': 'djvu',
#   'Mirror_1': 'http://library.lol/main/1D9FA59B0E4F522BF232C38E7FEA4757',
#   'Mirror_2': 'http://libgen.lc/ads.php?md5=1D9FA59B0E4F522BF232C38E7FEA4757',
# ...
